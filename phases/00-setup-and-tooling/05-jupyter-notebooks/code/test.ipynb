# %%
import random
import numpy as np

N = 100_000

# %timeit [random.random() for _ in range(N)]
# %timeit np.random.random(N)

print(len([random.random() for _ in range(N)]))
print(np.random.random(N).shape)
# Out:
# 2.05 ms ± 4.79 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 176 μs ± 407 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 100000
# (100000,)

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.032804315703168156), np.float64(1.0046091948894784))

# %%
# %timeit np.random.randn(10000)
# Out:
# 92.4 μs ± 1.87 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1,2.3,45.6]
})

df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.plot([1,2,3,4], [1,4,2,3])
plt.title("Inline plot")
plt.show()

# %%
from IPython.display import Image, display
display(Image(filename="notebook_plot.png"))
